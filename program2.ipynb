# %%
# Program 2: Stemming and Lemmatization on Sample Text
# Using NLTK

import nltk

# Download required resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Sample text
text = "The students are studying and playing games. They studied hard and played well."

print("Original Text:")
print(text)

# Tokenize the text
words = word_tokenize(text)

# Create Stemmer and Lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Stemming
print("\n--- Stemming ---")
for word in words:
    if word.isalpha():
        print(word, "->", stemmer.stem(word))

# Lemmatization
print("\n--- Lemmatization ---")
for word in words:
    if word.isalpha():
        print(word, "->", lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Original Text:
# The students are studying and playing games. They studied hard and played well.
#
# --- Stemming ---
# The -> the
# students -> student
# are -> are
# studying -> studi
# and -> and
# playing -> play
# games -> game
# They -> they
# studied -> studi
# hard -> hard
# and -> and
# played -> play
# well -> well
#
# --- Lemmatization ---
# The -> The
# students -> student
# are -> are
# studying -> studying
# and -> and
# playing -> playing
# games -> game
# They -> They
# studied -> studied
# hard -> hard
# and -> and
# played -> played
# well -> well
